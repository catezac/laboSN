# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.optimize import curve_fit
plt.rcParams.update({
    'font.family':'cmr10',
    'mathtext.fontset': 'cm',
    'axes.formatter.use_mathtext': True,
    'axes.axisbelow': True,
    'figure.figsize': [6.0, 6.0],
    'axes.labelsize': 15,
    'xtick.labelsize': 15,
    'ytick.labelsize': 15,
    'font.size':15,
    'savefig.directory':'./Images'
})

# %%
magn = np.loadtxt("NSL_SIMULATOR/OUTPUT/ENERGY/total_energy_summary.dat")
x = magn[:,0]
y = magn[:,2]
err = magn[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('temperature')
plt.ylabel('internal_energy')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/ENERGY/total_energy_0_3.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/ENERGY/total_energy__4.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)

plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/total_energy__4.dat")
#       2 x = susc[:,0]
#       3 y = susc[:,2]
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398             converters=converters, skiplines=skiprows, usecols=usecols,
#    1399             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1400             max_rows=max_rows, quote=quotechar)
#    1402 return arr
#
# ...

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/ENERGY/total_energy__5.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/total_energy__6.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/ENERGY/total_energy__7.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/ENERGY/total_energy__8.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/ENERGY/total_energy__9.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/ENERGY/total_energy_1_0.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/total_energy_1_1.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/total_energy_1_2.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/total_energy_1_3.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)
