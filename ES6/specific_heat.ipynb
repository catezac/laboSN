# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.optimize import curve_fit
plt.rcParams.update({
    'font.family':'cmr10',
    'mathtext.fontset': 'cm',
    'axes.formatter.use_mathtext': True,
    'axes.axisbelow': True,
    'figure.figsize': [6.0, 6.0],
    'axes.labelsize': 15,
    'xtick.labelsize': 15,
    'ytick.labelsize': 15,
    'font.size':15,
    'savefig.directory':'./Images'
})

# %%
magn = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat_summary.dat")
x = magn[:,0]
y = magn[:,2]
err = magn[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('temperature')
plt.ylabel('specific_heat')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat_0_3.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat__4.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat__5.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat__6.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat__7.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat__8.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat__9.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat_1_0.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat_1_1.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat_1_2.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)

# %%
susc = np.loadtxt("NSL_SIMULATOR/OUTPUT/HEAT_CAPACITY/specific_heat_1_3.dat")
x = susc[:,0]
y = susc[:,2]
err = susc[:,3]

plt.figure(1)
plt.errorbar(x,y,err, ecolor= 'orange' ,color='red')
plt.xlabel('block')
plt.ylabel('sceptibility')
plt.grid(True)
