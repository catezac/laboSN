# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory </span>
# ## <span style="color:brown"> Python Exercise 11 </span>
# ## <span style="color:orange"> Keras - Neural Network regression </span>

# %% [markdown]
# ### Overview
#
# In this notebook our task will be to perform machine learning regression on noisy data with a Neural Network (NN).
#
# We will explore how the ability to fit depends on the structure of the NN. The goal is also to build intuition about why prediction is difficult.

# %% [markdown]
# ### The Prediction Problem
#
# Consider a probabilistic process that gives rise to labeled data $(x,y)$. The data is generated by drawing samples from the equation
#
# $$
#     y_i= f(x_i) + \eta_i,
# $$
#
# where $f(x_i)$ is some fixed, but (possibly unknown) function, and $\eta_i$ is a Gaussian, uncorrelate noise variable such that
#
# $$
# \langle \eta_i \rangle=0 \\
# \langle \eta_i \eta_j \rangle = \delta_{ij} \sigma
# $$
#
# We will refer to the $f(x_i)$ as the **true features** used to generate the data.
#
# To make predictions, we will consider a NN that depends on its parameters, weights and biases. The functions that the NN can model respresent the **model class** that we are using to try to model the data and make predictions.
#
# To learn the parameters of the NN, we will train our models on a **training data set** and then test the effectiveness of the NN on a *different* dataset, the **validation data set**. The reason we must divide our data into a training and test dataset is that the point of machine learning is to make accurate predictions about new data we have not seen.
#
# To measure our ability to predict, we will learn our parameters by fitting our training dataset and then making predictions on our test data set. One common measure of predictive  performance of our algorithm is to compare the predictions,$\{y_j^\mathrm{pred}\}$, to the true values $\{y_j\}$. A commonly employed measure for this is the sum of the mean square-error (MSE) on the test set:
# $$
# MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
# $$
#
# We will try to get a qualitative picture by examining plots on validation and training data.

# %% [markdown]
# ### Linear fit
#
# We start by considering the very simple case:
# $$
# f(x)=2x+1
# $$

# %% [markdown]
# Let's start defining the parameters of an ideal linear function which we are going to predict through a neural network regression

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %% [markdown]
# Now let's generate a set of input data which will slightly deviate from our ideal behaviour using a random noise (that actually is set to zero):

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot validation and target dataset

import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# If you remember how a single node of a neural network works, you can easily spot that **just a single neuron can make the job**. So let's start using a simple Sequential model with just one layer on one neuron only!

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
# Out:
# 2025-06-20 12:15:39.356386: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-20 12:15:39.363141: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-20 12:15:39.398965: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-20 12:15:39.444982: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750414539.486246   33651 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750414539.499214   33651 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1750414539.588881   33651 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750414539.588925   33651 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750414539.588929   33651 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750414539.588931   33651 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-20 12:15:39.607363: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/catezac/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-06-20 12:15:42.392651: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We are now going to train our model, that is we feed the neuron with the set of training pair x, y_train from which the optimizer will find the best weights to minimize the Mean Square Error loss function (out linear regression function).

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=40,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4858 - mse: 4.4858 - val_loss: 3.5225 - val_mse: 3.5225
# Epoch 2/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4686 - mse: 3.4686 - val_loss: 2.7207 - val_mse: 2.7207
# Epoch 3/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7978 - mse: 2.7978 - val_loss: 2.1321 - val_mse: 2.1321
# Epoch 4/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1652 - mse: 2.1652 - val_loss: 1.6904 - val_mse: 1.6904
# Epoch 5/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7318 - mse: 1.7318 - val_loss: 1.3459 - val_mse: 1.3459
# Epoch 6/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4068 - mse: 1.4068 - val_loss: 1.0789 - val_mse: 1.0789
# Epoch 7/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1368 - mse: 1.1368 - val_loss: 0.8662 - val_mse: 0.8662
# Epoch 8/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9003 - mse: 0.9003 - val_loss: 0.6957 - val_mse: 0.6957
# Epoch 9/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6935 - mse: 0.6935 - val_loss: 0.5602 - val_mse: 0.5602
# Epoch 10/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5885 - mse: 0.5885 - val_loss: 0.4513 - val_mse: 0.4513
# Epoch 11/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4526 - mse: 0.4526 - val_loss: 0.3638 - val_mse: 0.3638
# Epoch 12/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3646 - mse: 0.3646 - val_loss: 0.2941 - val_mse: 0.2941
# Epoch 13/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2856 - mse: 0.2856 - val_loss: 0.2377 - val_mse: 0.2377
# Epoch 14/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2486 - mse: 0.2486 - val_loss: 0.1926 - val_mse: 0.1926
# Epoch 15/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2123 - mse: 0.2123 - val_loss: 0.1568 - val_mse: 0.1568
# Epoch 16/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1679 - mse: 0.1679 - val_loss: 0.1280 - val_mse: 0.1280
# Epoch 17/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1279 - mse: 0.1279 - val_loss: 0.1046 - val_mse: 0.1046
# Epoch 18/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1177 - mse: 0.1177 - val_loss: 0.0857 - val_mse: 0.0857
# Epoch 19/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0906 - mse: 0.0906 - val_loss: 0.0707 - val_mse: 0.0707
# Epoch 20/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0692 - mse: 0.0692 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 21/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0591 - mse: 0.0591 - val_loss: 0.0491 - val_mse: 0.0491
# Epoch 22/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0513 - mse: 0.0513 - val_loss: 0.0414 - val_mse: 0.0414
# Epoch 23/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.0353 - val_mse: 0.0353
# Epoch 24/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0362 - mse: 0.0362 - val_loss: 0.0304 - val_mse: 0.0304
# Epoch 25/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0315 - mse: 0.0315 - val_loss: 0.0265 - val_mse: 0.0265
# Epoch 26/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0265 - mse: 0.0265 - val_loss: 0.0233 - val_mse: 0.0233
# Epoch 27/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0208 - val_mse: 0.0208
# Epoch 28/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 29/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0172 - val_mse: 0.0172
# Epoch 30/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0159 - val_mse: 0.0159
# Epoch 31/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 32/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 33/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 34/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 35/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 36/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 37/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 38/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 39/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 40/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0114 - val_mse: 0.0114

# %% [markdown]
# By looking at weights and biases we can see if the linear fit was successfull: $w_1$ represents the angular coefficient, $b$ the intercept.

# %%
# return weights and biases
model.get_weights()
# Out:
# [array([[1.965412]], dtype=float32), array([0.98937804], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0111 - mse: 0.0111
#
# Test loss: 0.011420979164540768
# Test accuracy: 0.011420979164540768

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.6719e-04 - mse: 3.6719e-04
#
# Test loss: 0.00045598187716677785
# Test accuracy: 0.00045598187716677785

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted_40 = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# con il train modifico i parmateri, con il valid calcolo la loss per capire se i parametri che ho trovato nel train sono giusti

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# Find good (& reasonable) choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Check your NN model by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %%
# target parameters of f(x) = ax^3 +b x^2 +c x +d
a = 3 
b = -2
c = - 3
d = 4

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train_pol = np.random.uniform(-1, 1, 500)
x_valid_pol = np.random.uniform(-1, 1, 50)
x_valid_pol.sort()
y_target_pol = d + c* x_valid_pol +b * x_valid_pol**2 + a * x_valid_pol**3  # ideal (target) linear function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train_pol = np.random.normal(d + c* x_train_pol+b * x_train_pol**2 + a * x_train_pol**3 , sigma) # actual measures from which we want to guess regression parameters
y_valid_pol = np.random.normal(d + c* x_valid_pol +b * x_valid_pol**2 + a * x_valid_pol**3 , sigma)

# %%
# plot validation and target dataset

import matplotlib.pyplot as plt
plt.plot(x_valid_pol, y_target_pol, label='target')
plt.scatter(x_valid_pol, y_valid_pol, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(4, input_shape=(1,), activation='relu'))
model.add(Dense(16, input_shape=(1,), activation='relu'))
model.add(Dense(16, input_shape=(1,), activation='relu'))
model.add(Dense(4, input_shape=(1,), activation='relu'))
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 4)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 4)              │            68 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 433 (1.69 KB)
#  Trainable params: 433 (1.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train_pol, y=y_train_pol, 
          batch_size=32, epochs=60,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid_pol, y_valid_pol))
# Out:
# Epoch 1/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.5826 - mse: 8.5826 - val_loss: 1.0520 - val_mse: 1.0520
# Epoch 2/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7466 - mse: 0.7466 - val_loss: 0.8946 - val_mse: 0.8946
# Epoch 3/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7227 - mse: 0.7227 - val_loss: 0.8947 - val_mse: 0.8947
# Epoch 4/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6567 - mse: 0.6567 - val_loss: 0.8332 - val_mse: 0.8332
# Epoch 5/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6361 - mse: 0.6361 - val_loss: 0.8181 - val_mse: 0.8181
# Epoch 6/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6048 - mse: 0.6048 - val_loss: 0.8356 - val_mse: 0.8356
# Epoch 7/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5635 - mse: 0.5635 - val_loss: 0.8036 - val_mse: 0.8036
# Epoch 8/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6044 - mse: 0.6044 - val_loss: 0.8573 - val_mse: 0.8573
# Epoch 9/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5823 - mse: 0.5823 - val_loss: 0.8015 - val_mse: 0.8015
# Epoch 10/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6026 - mse: 0.6026 - val_loss: 0.8107 - val_mse: 0.8107
# Epoch 11/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6002 - mse: 0.6002 - val_loss: 0.7930 - val_mse: 0.7930
# Epoch 12/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6050 - mse: 0.6050 - val_loss: 0.7901 - val_mse: 0.7901
# Epoch 13/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5896 - mse: 0.5896 - val_loss: 0.7908 - val_mse: 0.7908
# Epoch 14/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5205 - mse: 0.5205 - val_loss: 0.7939 - val_mse: 0.7939
# Epoch 15/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5786 - mse: 0.5786 - val_loss: 0.7805 - val_mse: 0.7805
# Epoch 16/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5402 - mse: 0.5402 - val_loss: 0.7830 - val_mse: 0.7830
# Epoch 17/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5581 - mse: 0.5581 - val_loss: 0.8329 - val_mse: 0.8329
# Epoch 18/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5850 - mse: 0.5850 - val_loss: 0.7714 - val_mse: 0.7714
# Epoch 19/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5576 - mse: 0.5576 - val_loss: 0.7779 - val_mse: 0.7779
# Epoch 20/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5239 - mse: 0.5239 - val_loss: 0.7895 - val_mse: 0.7895
# Epoch 21/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5133 - mse: 0.5133 - val_loss: 0.7768 - val_mse: 0.7768
# Epoch 22/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5829 - mse: 0.5829 - val_loss: 0.8017 - val_mse: 0.8017
# Epoch 23/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5533 - mse: 0.5533 - val_loss: 0.7952 - val_mse: 0.7952
# Epoch 24/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4658 - mse: 0.4658 - val_loss: 0.7328 - val_mse: 0.7328
# Epoch 25/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5276 - mse: 0.5276 - val_loss: 0.7228 - val_mse: 0.7228
# Epoch 26/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4465 - mse: 0.4465 - val_loss: 0.7429 - val_mse: 0.7429
# Epoch 27/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5055 - mse: 0.5055 - val_loss: 0.6881 - val_mse: 0.6881
# Epoch 28/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5200 - mse: 0.5200 - val_loss: 0.6720 - val_mse: 0.6720
# Epoch 29/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4183 - mse: 0.4183 - val_loss: 0.6341 - val_mse: 0.6341
# Epoch 30/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.4589 - mse: 0.4589 - val_loss: 0.6616 - val_mse: 0.6616
# Epoch 31/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3728 - mse: 0.3728 - val_loss: 0.5979 - val_mse: 0.5979
# Epoch 32/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4039 - mse: 0.4039 - val_loss: 0.5593 - val_mse: 0.5593
# Epoch 33/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4238 - mse: 0.4238 - val_loss: 0.5365 - val_mse: 0.5365
# Epoch 34/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3310 - mse: 0.3310 - val_loss: 0.5040 - val_mse: 0.5040
# Epoch 35/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3429 - mse: 0.3429 - val_loss: 0.4513 - val_mse: 0.4513
# Epoch 36/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2889 - mse: 0.2889 - val_loss: 0.4224 - val_mse: 0.4224
# Epoch 37/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2886 - mse: 0.2886 - val_loss: 0.3747 - val_mse: 0.3747
# Epoch 38/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2251 - mse: 0.2251 - val_loss: 0.3444 - val_mse: 0.3444
# Epoch 39/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2211 - mse: 0.2211 - val_loss: 0.2904 - val_mse: 0.2904
# Epoch 40/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1627 - mse: 0.1627 - val_loss: 0.2370 - val_mse: 0.2370
# Epoch 41/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1667 - mse: 0.1667 - val_loss: 0.2133 - val_mse: 0.2133
# Epoch 42/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1351 - mse: 0.1351 - val_loss: 0.1947 - val_mse: 0.1947
# Epoch 43/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1117 - mse: 0.1117 - val_loss: 0.1345 - val_mse: 0.1345
# Epoch 44/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0944 - mse: 0.0944 - val_loss: 0.1317 - val_mse: 0.1317
# Epoch 45/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0802 - mse: 0.0802 - val_loss: 0.0969 - val_mse: 0.0969
# Epoch 46/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0735 - mse: 0.0735 - val_loss: 0.1783 - val_mse: 0.1783
# Epoch 47/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0767 - mse: 0.0767 - val_loss: 0.0919 - val_mse: 0.0919
# Epoch 48/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0468 - mse: 0.0468 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 49/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0453 - mse: 0.0453 - val_loss: 0.0504 - val_mse: 0.0504
# Epoch 50/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0427 - mse: 0.0427 - val_loss: 0.0480 - val_mse: 0.0480
# Epoch 51/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0352 - mse: 0.0352 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 52/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0318 - mse: 0.0318 - val_loss: 0.0451 - val_mse: 0.0451
# Epoch 53/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0349 - mse: 0.0349 - val_loss: 0.0376 - val_mse: 0.0376
# Epoch 54/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0306 - mse: 0.0306 - val_loss: 0.0401 - val_mse: 0.0401
# Epoch 55/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0268 - mse: 0.0268 - val_loss: 0.0420 - val_mse: 0.0420
# Epoch 56/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0329 - mse: 0.0329 - val_loss: 0.0319 - val_mse: 0.0319
# Epoch 57/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0284 - mse: 0.0284 - val_loss: 0.0348 - val_mse: 0.0348
# Epoch 58/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0278 - val_mse: 0.0278
# Epoch 59/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0247 - mse: 0.0247 - val_loss: 0.0270 - val_mse: 0.0270
# Epoch 60/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0282 - mse: 0.0282 - val_loss: 0.0256 - val_mse: 0.0256

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted_pol = np.random.uniform(-2, 2, 100)
y_predicted_pol = model.predict(x_predicted_pol)
plt.scatter(x_predicted_pol, y_predicted_pol,color='r')
plt.plot(x_valid_pol, y_target_pol)
plt.grid(True)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train_3 = np.random.uniform(-3/2, 3/2, 150)
y_train_3 = np.random.uniform(-3/2, 3/2, 150)
x_valid_3 = np.random.uniform(-3/2, 3/2, 50)
y_valid_3 = np.random.uniform(-3/2, 3/2, 50)
x_valid_3.sort()
y_valid_3.sort()

X_valid_3, Y_valid_3 = np.meshgrid(x_valid_3, y_valid_3)
X_train_3, Y_train_3 = np.meshgrid(x_train_3, y_train_3)



print(X_valid_3.shape)
print(Y_valid_3.shape)

z_target_3 = np.sin(X_valid_3**2+Y_valid_3**2)  # ideal (target)  function

sigma = 0.1 # noise standard deviation, for the moment it is absent
z_train_3 = np.random.normal(np.sin(X_train_3**2+Y_train_3**2) , sigma) # actual measures from which we want to guess regression parameters
z_valid_3 = np.random.normal(np.sin(X_valid_3**2+Y_valid_3**2) , sigma)
print(z_valid_3.shape)
# Out:
# (50, 50)
# (50, 50)
# (50, 50)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.figure()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_valid_3, Y_valid_3, z_valid_3)
ax.plot_surface(X_valid_3, Y_valid_3, np.sin(X_valid_3**2 + Y_valid_3**2), cmap='viridis')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_33651/1450241792.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model_sin = tf.keras.Sequential()
model_sin.add(Dense(4, input_shape=(2,), activation='relu'))
model_sin.add(Dense(16, activation='relu'))
model_sin.add(Dense(16, activation='relu'))
model_sin.add(Dense(4, activation='relu'))
model_sin.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model_sin.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model_sin.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 4)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 4)              │            68 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 437 (1.71 KB)
#  Trainable params: 437 (1.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
#X_tr = np.stack((X_train_3, Y_train_3), axis = 1 ) # shape (N, 2)
X_val = np.column_stack((X_valid_3.ravel(), Y_valid_3.ravel()))  # shape (N_valid, 2)
X_train = np.column_stack((X_train_3.ravel(), Y_train_3.ravel())) 

Z_train = z_train_3.ravel()
Z_valid = z_valid_3.ravel()

history = model_sin.fit(x = X_train , y=Z_train,
          batch_size=32, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(X_val, Z_valid))
# Out:
# Epoch 1/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1813 - mse: 0.1813 - val_loss: 0.1317 - val_mse: 0.1317
# Epoch 2/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1420 - mse: 0.1420 - val_loss: 0.1116 - val_mse: 0.1116
# Epoch 3/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1207 - mse: 0.1207 - val_loss: 0.0795 - val_mse: 0.0795
# Epoch 4/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0916 - mse: 0.0916 - val_loss: 0.0599 - val_mse: 0.0599
# Epoch 5/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0708 - mse: 0.0708 - val_loss: 0.0493 - val_mse: 0.0493
# Epoch 6/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0610 - mse: 0.0610 - val_loss: 0.0465 - val_mse: 0.0465
# Epoch 7/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0553 - mse: 0.0553 - val_loss: 0.0493 - val_mse: 0.0493
# Epoch 8/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0529 - mse: 0.0529 - val_loss: 0.0402 - val_mse: 0.0402
# Epoch 9/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0518 - mse: 0.0518 - val_loss: 0.0413 - val_mse: 0.0413
# Epoch 10/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0512 - mse: 0.0512 - val_loss: 0.0471 - val_mse: 0.0471
# Epoch 11/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0505 - mse: 0.0505 - val_loss: 0.0386 - val_mse: 0.0386
# Epoch 12/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0511 - mse: 0.0511 - val_loss: 0.0400 - val_mse: 0.0400
# Epoch 13/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0407 - val_mse: 0.0407
# Epoch 14/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0482 - mse: 0.0482 - val_loss: 0.0386 - val_mse: 0.0386
# Epoch 15/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0396 - val_mse: 0.0396
# Epoch 16/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0479 - mse: 0.0479 - val_loss: 0.0368 - val_mse: 0.0368
# Epoch 17/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0479 - mse: 0.0479 - val_loss: 0.0379 - val_mse: 0.0379
# Epoch 18/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0474 - mse: 0.0474 - val_loss: 0.0374 - val_mse: 0.0374
# Epoch 19/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0476 - mse: 0.0476 - val_loss: 0.0354 - val_mse: 0.0354
# Epoch 20/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0467 - mse: 0.0467 - val_loss: 0.0350 - val_mse: 0.0350
# Epoch 21/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0469 - mse: 0.0469 - val_loss: 0.0363 - val_mse: 0.0363
# Epoch 22/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0462 - mse: 0.0462 - val_loss: 0.0341 - val_mse: 0.0341
# Epoch 23/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0440 - mse: 0.0440 - val_loss: 0.0370 - val_mse: 0.0370
# Epoch 24/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0456 - mse: 0.0456 - val_loss: 0.0333 - val_mse: 0.0333
# Epoch 25/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0431 - mse: 0.0431 - val_loss: 0.0339 - val_mse: 0.0339
# Epoch 26/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0312 - val_mse: 0.0312
# Epoch 27/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0395 - mse: 0.0395 - val_loss: 0.0318 - val_mse: 0.0318
# Epoch 28/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0384 - mse: 0.0384 - val_loss: 0.0276 - val_mse: 0.0276
# Epoch 29/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0343 - mse: 0.0343 - val_loss: 0.0264 - val_mse: 0.0264
# Epoch 30/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0308 - mse: 0.0308 - val_loss: 0.0234 - val_mse: 0.0234
# Epoch 31/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0264 - mse: 0.0264 - val_loss: 0.0297 - val_mse: 0.0297
# Epoch 32/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 33/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0172 - val_mse: 0.0172
# Epoch 34/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 35/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0264 - val_mse: 0.0264
# Epoch 36/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0198 - val_mse: 0.0198
# Epoch 37/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 38/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 39/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 40/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 41/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 42/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 43/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 44/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 45/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 46/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 47/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 48/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 49/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 50/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0124 - val_mse: 0.0124

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted_3 = np.random.uniform(-3/2, 3/2, 100)
y_predicted_3 = np.random.uniform(-3/2,3/2, 100)

x_predicted_3.sort()
y_predicted_3.sort()

X_pred, Y_pred = np.meshgrid(x_predicted_3, y_predicted_3)

X_prediction = np.column_stack((X_pred.ravel(), Y_pred.ravel()))
Z_pred = model_sin.predict(X_prediction).reshape(X_pred.shape)

print(X_prediction.shape)
#print(X_pred)
print(Y_pred.shape)
print(Z_pred.shape)

# plot validation and target dataset
plt.figure()
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.scatter(X_pred, Y_pred, Z_pred, s=1)
Z = np.sin(X_pred**2+Y_pred**2)
ax1.plot_surface(X_pred, Y_pred, Z, cmap='viridis')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b438c5420e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (10000, 2)
# (100, 100)
# (100, 100)
# /tmp/ipykernel_33651/3907518543.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
