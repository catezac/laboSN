# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory </span>
# ## <span style="color:brown"> Python Exercise 11 </span>
# ## <span style="color:orange"> Keras - Neural Network regression </span>

# %% [markdown]
# ### Overview
#
# In this notebook our task will be to perform machine learning regression on noisy data with a Neural Network (NN).
#
# We will explore how the ability to fit depends on the structure of the NN. The goal is also to build intuition about why prediction is difficult.

# %% [markdown]
# ### The Prediction Problem
#
# Consider a probabilistic process that gives rise to labeled data $(x,y)$. The data is generated by drawing samples from the equation
#
# $$
#     y_i= f(x_i) + \eta_i,
# $$
#
# where $f(x_i)$ is some fixed, but (possibly unknown) function, and $\eta_i$ is a Gaussian, uncorrelate noise variable such that
#
# $$
# \langle \eta_i \rangle=0 \\
# \langle \eta_i \eta_j \rangle = \delta_{ij} \sigma
# $$
#
# We will refer to the $f(x_i)$ as the **true features** used to generate the data.
#
# To make predictions, we will consider a NN that depends on its parameters, weights and biases. The functions that the NN can model respresent the **model class** that we are using to try to model the data and make predictions.
#
# To learn the parameters of the NN, we will train our models on a **training data set** and then test the effectiveness of the NN on a *different* dataset, the **validation data set**. The reason we must divide our data into a training and test dataset is that the point of machine learning is to make accurate predictions about new data we have not seen.
#
# To measure our ability to predict, we will learn our parameters by fitting our training dataset and then making predictions on our test data set. One common measure of predictive  performance of our algorithm is to compare the predictions,$\{y_j^\mathrm{pred}\}$, to the true values $\{y_j\}$. A commonly employed measure for this is the sum of the mean square-error (MSE) on the test set:
# $$
# MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
# $$
#
# We will try to get a qualitative picture by examining plots on validation and training data.

# %% [markdown]
# ### Linear fit
#
# We start by considering the very simple case:
# $$
# f(x)=2x+1
# $$

# %% [markdown]
# Let's start defining the parameters of an ideal linear function which we are going to predict through a neural network regression

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %% [markdown]
# Now let's generate a set of input data which will slightly deviate from our ideal behaviour using a random noise (that actually is set to zero):

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot validation and target dataset

import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# If you remember how a single node of a neural network works, you can easily spot that **just a single neuron can make the job**. So let's start using a simple Sequential model with just one layer on one neuron only!

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
# Out:
# /home/catezac/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We are now going to train our model, that is we feed the neuron with the set of training pair x, y_train from which the optimizer will find the best weights to minimize the Mean Square Error loss function (out linear regression function).

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=40,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0351 - mse: 1.0351 - val_loss: 0.6819 - val_mse: 0.6819
# Epoch 2/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5644 - mse: 0.5644 - val_loss: 0.4078 - val_mse: 0.4078
# Epoch 3/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3725 - mse: 0.3725 - val_loss: 0.2563 - val_mse: 0.2563
# Epoch 4/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2390 - mse: 0.2390 - val_loss: 0.1684 - val_mse: 0.1684
# Epoch 5/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1501 - mse: 0.1501 - val_loss: 0.1169 - val_mse: 0.1169
# Epoch 6/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0977 - mse: 0.0977 - val_loss: 0.0845 - val_mse: 0.0845
# Epoch 7/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0850 - mse: 0.0850 - val_loss: 0.0641 - val_mse: 0.0641
# Epoch 8/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0530 - mse: 0.0530 - val_loss: 0.0503 - val_mse: 0.0503
# Epoch 9/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0432 - mse: 0.0432 - val_loss: 0.0407 - val_mse: 0.0407
# Epoch 10/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0372 - mse: 0.0372 - val_loss: 0.0337 - val_mse: 0.0337
# Epoch 11/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0286 - val_mse: 0.0286
# Epoch 12/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0265 - mse: 0.0265 - val_loss: 0.0246 - val_mse: 0.0246
# Epoch 13/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0222 - mse: 0.0222 - val_loss: 0.0216 - val_mse: 0.0216
# Epoch 14/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 15/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 16/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 17/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 18/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 19/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 20/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 21/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 22/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 23/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 24/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 25/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 26/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 27/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 28/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 29/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 30/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 31/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 32/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 33/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 34/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 35/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 36/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 37/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 38/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 39/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 40/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0111 - val_mse: 0.0111

# %% [markdown]
# By looking at weights and biases we can see if the linear fit was successfull: $w_1$ represents the angular coefficient, $b$ the intercept.

# %%
# return weights and biases
model.get_weights()
# Out:
# [array([[2.0013444]], dtype=float32), array([0.98898584], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0112 - mse: 0.0112
#
# Test loss: 0.011131107807159424
# Test accuracy: 0.011131107807159424

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2675e-04 - mse: 1.2675e-04
#
# Test loss: 0.00012343884736765176
# Test accuracy: 0.00012343884736765176

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %% [markdown]
# con il train modifico i parmateri, con il valid calcolo la loss per capire se i parametri che ho trovato nel train sono giusti

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# Find good (& reasonable) choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Check your NN model by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %%
# target parameters of f(x) = ax^3 +b x^2 +c x +d
a = 3 
b = -2
c = - 3
d = 4

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train_pol = np.random.uniform(-1, 1, 500)
x_valid_pol = np.random.uniform(-1, 1, 50)
x_valid_pol.sort()
y_target_pol = d + c* x_valid_pol +b * x_valid_pol**2 + a * x_valid_pol**3  # ideal (target) linear function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train_pol = np.random.normal(d + c* x_train_pol+b * x_train_pol**2 + a * x_train_pol**3 , sigma) # actual measures from which we want to guess regression parameters
y_valid_pol = np.random.normal(d + c* x_valid_pol +b * x_valid_pol**2 + a * x_valid_pol**3 , sigma)

# %%
# plot validation and target dataset

import matplotlib.pyplot as plt
plt.plot(x_valid_pol, y_target_pol, label='target')
plt.scatter(x_valid_pol, y_valid_pol, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(4, input_shape=(1,), activation='relu'))
model.add(Dense(16, input_shape=(1,), activation='relu'))
model.add(Dense(16, input_shape=(1,), activation='relu'))
model.add(Dense(4, input_shape=(1,), activation='relu'))
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_16 (Dense)                │ (None, 4)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 4)              │            68 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 433 (1.69 KB)
#  Trainable params: 433 (1.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train_pol, y=y_train_pol, 
          batch_size=40, epochs=60,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid_pol, y_valid_pol))
# Out:
# Epoch 1/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.7598 - mse: 10.7598 - val_loss: 6.6038 - val_mse: 6.6038
# Epoch 2/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3918 - mse: 5.3918 - val_loss: 2.2559 - val_mse: 2.2559
# Epoch 3/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7700 - mse: 1.7700 - val_loss: 0.8643 - val_mse: 0.8643
# Epoch 4/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7620 - mse: 0.7620 - val_loss: 0.5624 - val_mse: 0.5624
# Epoch 5/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4171 - mse: 0.4171 - val_loss: 0.4411 - val_mse: 0.4411
# Epoch 6/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3351 - mse: 0.3351 - val_loss: 0.4239 - val_mse: 0.4239
# Epoch 7/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3040 - mse: 0.3040 - val_loss: 0.4250 - val_mse: 0.4250
# Epoch 8/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2700 - mse: 0.2700 - val_loss: 0.4354 - val_mse: 0.4354
# Epoch 9/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2306 - mse: 0.2306 - val_loss: 0.4155 - val_mse: 0.4155
# Epoch 10/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2751 - mse: 0.2751 - val_loss: 0.4144 - val_mse: 0.4144
# Epoch 11/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2528 - mse: 0.2528 - val_loss: 0.4167 - val_mse: 0.4167
# Epoch 12/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2696 - mse: 0.2696 - val_loss: 0.4137 - val_mse: 0.4137
# Epoch 13/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2688 - mse: 0.2688 - val_loss: 0.4164 - val_mse: 0.4164
# Epoch 14/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3088 - mse: 0.3088 - val_loss: 0.4178 - val_mse: 0.4178
# Epoch 15/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2514 - mse: 0.2514 - val_loss: 0.4057 - val_mse: 0.4057
# Epoch 16/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2663 - mse: 0.2663 - val_loss: 0.4015 - val_mse: 0.4015
# Epoch 17/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2217 - mse: 0.2217 - val_loss: 0.3976 - val_mse: 0.3976
# Epoch 18/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2525 - mse: 0.2525 - val_loss: 0.3925 - val_mse: 0.3925
# Epoch 19/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2618 - mse: 0.2618 - val_loss: 0.3916 - val_mse: 0.3916
# Epoch 20/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2770 - mse: 0.2770 - val_loss: 0.3872 - val_mse: 0.3872
# Epoch 21/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2039 - mse: 0.2039 - val_loss: 0.3791 - val_mse: 0.3791
# Epoch 22/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2815 - mse: 0.2815 - val_loss: 0.3897 - val_mse: 0.3897
# Epoch 23/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2360 - mse: 0.2360 - val_loss: 0.3729 - val_mse: 0.3729
# Epoch 24/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2392 - mse: 0.2392 - val_loss: 0.3699 - val_mse: 0.3699
# Epoch 25/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2153 - mse: 0.2153 - val_loss: 0.3595 - val_mse: 0.3595
# Epoch 26/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2388 - mse: 0.2388 - val_loss: 0.3647 - val_mse: 0.3647
# Epoch 27/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2045 - mse: 0.2045 - val_loss: 0.3503 - val_mse: 0.3503
# Epoch 28/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2303 - mse: 0.2303 - val_loss: 0.3411 - val_mse: 0.3411
# Epoch 29/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1982 - mse: 0.1982 - val_loss: 0.3299 - val_mse: 0.3299
# Epoch 30/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2131 - mse: 0.2131 - val_loss: 0.3188 - val_mse: 0.3188
# Epoch 31/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1735 - mse: 0.1735 - val_loss: 0.3040 - val_mse: 0.3040
# Epoch 32/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1480 - mse: 0.1480 - val_loss: 0.2854 - val_mse: 0.2854
# Epoch 33/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1938 - mse: 0.1938 - val_loss: 0.2746 - val_mse: 0.2746
# Epoch 34/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1784 - mse: 0.1784 - val_loss: 0.2595 - val_mse: 0.2595
# Epoch 35/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1774 - mse: 0.1774 - val_loss: 0.2538 - val_mse: 0.2538
# Epoch 36/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1538 - mse: 0.1538 - val_loss: 0.2430 - val_mse: 0.2430
# Epoch 37/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1672 - mse: 0.1672 - val_loss: 0.2305 - val_mse: 0.2305
# Epoch 38/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1369 - mse: 0.1369 - val_loss: 0.2116 - val_mse: 0.2116
# Epoch 39/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1426 - mse: 0.1426 - val_loss: 0.2070 - val_mse: 0.2070
# Epoch 40/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1426 - mse: 0.1426 - val_loss: 0.1920 - val_mse: 0.1920
# Epoch 41/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1362 - mse: 0.1362 - val_loss: 0.1799 - val_mse: 0.1799
# Epoch 42/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1231 - mse: 0.1231 - val_loss: 0.1701 - val_mse: 0.1701
# Epoch 43/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1109 - mse: 0.1109 - val_loss: 0.1599 - val_mse: 0.1599
# Epoch 44/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1121 - mse: 0.1121 - val_loss: 0.1497 - val_mse: 0.1497
# Epoch 45/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0988 - mse: 0.0988 - val_loss: 0.1379 - val_mse: 0.1379
# Epoch 46/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0996 - mse: 0.0996 - val_loss: 0.1301 - val_mse: 0.1301
# Epoch 47/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1079 - mse: 0.1079 - val_loss: 0.1312 - val_mse: 0.1312
# Epoch 48/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0825 - mse: 0.0825 - val_loss: 0.1161 - val_mse: 0.1161
# Epoch 49/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0883 - mse: 0.0883 - val_loss: 0.1081 - val_mse: 0.1081
# Epoch 50/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0832 - mse: 0.0832 - val_loss: 0.1082 - val_mse: 0.1082
# Epoch 51/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0727 - mse: 0.0727 - val_loss: 0.0961 - val_mse: 0.0961
# Epoch 52/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0697 - mse: 0.0697 - val_loss: 0.0913 - val_mse: 0.0913
# Epoch 53/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0732 - mse: 0.0732 - val_loss: 0.0889 - val_mse: 0.0889
# Epoch 54/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0739 - mse: 0.0739 - val_loss: 0.0898 - val_mse: 0.0898
# Epoch 55/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0704 - mse: 0.0704 - val_loss: 0.0765 - val_mse: 0.0765
# Epoch 56/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0644 - mse: 0.0644 - val_loss: 0.0726 - val_mse: 0.0726
# Epoch 57/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0525 - mse: 0.0525 - val_loss: 0.0669 - val_mse: 0.0669
# Epoch 58/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0501 - mse: 0.0501 - val_loss: 0.0701 - val_mse: 0.0701
# Epoch 59/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 60/60
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0478 - mse: 0.0478 - val_loss: 0.0548 - val_mse: 0.0548

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted_pol = np.random.uniform(-2, 2, 100)
y_predicted_pol = model.predict(x_predicted_pol)
plt.scatter(x_predicted_pol, y_predicted_pol,color='r')
plt.plot(x_valid_pol, y_target_pol)
plt.grid(True)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train_3 = np.random.uniform(-3/2, 3/2, 150)
y_train_3 = np.random.uniform(-3/2, 3/2, 150)
x_valid_3 = np.random.uniform(-3/2, 3/2, 50)
y_valid_3 = np.random.uniform(-3/2, 3/2, 50)
x_valid_3.sort()
y_valid_3.sort()

X_valid_3, Y_valid_3 = np.meshgrid(x_valid_3, y_valid_3)
X_train_3, Y_train_3 = np.meshgrid(x_train_3, y_train_3)



print(X_valid_3.shape)
print(Y_valid_3.shape)

z_target_3 = np.sin(X_valid_3**2+Y_valid_3**2)  # ideal (target)  function

sigma = 0.1 # noise standard deviation, for the moment it is absent
z_train_3 = np.random.normal(np.sin(X_train_3**2+Y_train_3**2) , sigma) # actual measures from which we want to guess regression parameters
z_valid_3 = np.random.normal(np.sin(X_valid_3**2+Y_valid_3**2) , sigma)
print(z_valid_3.shape)
# Out:
# (50, 50)
# (50, 50)
# (50, 50)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.figure()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_valid_3, Y_valid_3, z_valid_3)
ax.plot_surface(X_valid_3, Y_valid_3, np.sin(X_valid_3**2 + Y_valid_3**2), cmap='viridis')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_954/1450241792.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model_sin = tf.keras.Sequential()
model_sin.add(Dense(4, input_shape=(2,), activation='relu'))
model_sin.add(Dense(16, activation='relu'))
model_sin.add(Dense(16, activation='relu'))
model_sin.add(Dense(4, activation='relu'))
model_sin.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model_sin.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model_sin.summary()
# Out:
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_91 (Dense)                │ (None, 4)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_92 (Dense)                │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_93 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_94 (Dense)                │ (None, 4)              │            68 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_95 (Dense)                │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 437 (1.71 KB)
#  Trainable params: 437 (1.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
#X_tr = np.stack((X_train_3, Y_train_3), axis = 1 ) # shape (N, 2)
X_val = np.column_stack((X_valid_3.ravel(), Y_valid_3.ravel()))  # shape (N_valid, 2)
X_train = np.column_stack((X_train_3.ravel(), Y_train_3.ravel())) 

Z_train = z_train_3.ravel()
Z_valid = z_valid_3.ravel()

history = model_sin.fit(x = X_train , y=Z_train,
          batch_size=32, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(X_val, Z_valid))
# Out:
# Epoch 1/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1771 - mse: 0.1771 - val_loss: 0.1303 - val_mse: 0.1303
# Epoch 2/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1390 - mse: 0.1390 - val_loss: 0.1151 - val_mse: 0.1151
# Epoch 3/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1188 - mse: 0.1188 - val_loss: 0.0975 - val_mse: 0.0975
# Epoch 4/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1027 - mse: 0.1027 - val_loss: 0.0869 - val_mse: 0.0869
# Epoch 5/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0906 - mse: 0.0906 - val_loss: 0.0817 - val_mse: 0.0817
# Epoch 6/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0846 - mse: 0.0846 - val_loss: 0.0740 - val_mse: 0.0740
# Epoch 7/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0755 - mse: 0.0755 - val_loss: 0.0625 - val_mse: 0.0625
# Epoch 8/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0668 - mse: 0.0668 - val_loss: 0.0526 - val_mse: 0.0526
# Epoch 9/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0448 - val_mse: 0.0448
# Epoch 10/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0520 - mse: 0.0520 - val_loss: 0.0383 - val_mse: 0.0383
# Epoch 11/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0468 - mse: 0.0468 - val_loss: 0.0309 - val_mse: 0.0309
# Epoch 12/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0383 - mse: 0.0383 - val_loss: 0.0250 - val_mse: 0.0250
# Epoch 13/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0297 - mse: 0.0297 - val_loss: 0.0236 - val_mse: 0.0236
# Epoch 14/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0220 - mse: 0.0220 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 15/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 16/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0256 - val_mse: 0.0256
# Epoch 17/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 18/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 19/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 20/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 21/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 22/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 23/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 24/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 25/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0151 - val_mse: 0.0151
# Epoch 26/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 27/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 28/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 29/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 30/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 31/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 32/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 33/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 34/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 35/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 36/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 37/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 38/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 39/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 40/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 41/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 42/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 43/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 44/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 45/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 46/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 47/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 48/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 49/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 50/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0122 - val_mse: 0.0122

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted_3 = np.random.uniform(-3/2, 3/2, 100)
y_predicted_3 = np.random.uniform(-3/2,3/2, 100)

x_predicted_3.sort()
y_predicted_3.sort()

X_pred, Y_pred = np.meshgrid(x_predicted_3, y_predicted_3)

X_prediction = np.column_stack((X_pred.ravel(), Y_pred.ravel()))
Z_pred = model_sin.predict(X_prediction).reshape(X_pred.shape)

print(X_prediction.shape)
#print(X_pred)
print(Y_pred.shape)
print(Z_pred.shape)

# plot validation and target dataset
plt.figure()
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.scatter(X_pred, Y_pred, Z_pred, s=1)
Z = np.sin(X_pred**2+Y_pred**2)
ax1.plot_surface(X_pred, Y_pred, Z, cmap='viridis')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#   1/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step
# (10000, 2)
# (100, 100)
# (100, 100)
# /tmp/ipykernel_954/3907518543.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
